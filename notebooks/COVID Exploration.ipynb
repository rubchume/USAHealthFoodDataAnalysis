# %%
import pandas as pd

# %% [markdown]
# # Vaccinations

# %%
vaccinations_file = "../data/CentersForDiseaseControlAndPrevention/COVID-19_Vaccinations_in_the_United_States_County.csv"

# %%
df = pd.read_csv(vaccinations_file)
# Out:
# /var/folders/hz/xl7p3y2s2131w7ry5byqrr5c0000gn/T/ipykernel_40479/4170687349.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(vaccinations_file)

# %%
df.head()
# Out:
#          Date   FIPS  MMWR_week       Recip_County Recip_State  \
# 0  11/09/2022  21159         45      Martin County          KY
# 1  11/09/2022  17067         45     Hancock County          IL
# 2  11/09/2022  26127         45      Oceana County          MI
# 3  11/09/2022  29119         45    McDonald County          MO
# 4  11/09/2022  35001         45  Bernalillo County          NM
#
#    Completeness_pct  Administered_Dose1_Recip  Administered_Dose1_Pop_Pct  \
# 0              94.1                    6935.0                        61.9
# 1              98.2                   10678.0                        60.3
# 2              94.4                       NaN                         NaN
# 3              91.3                   10323.0                        45.2
# 4              97.0                  610486.0                        89.9
#
#    Administered_Dose1_Recip_5Plus  Administered_Dose1_Recip_5PlusPop_Pct  ...  \
# ...

# %% [markdown]
# # COVID cases

# %%
covid_file = "../data/Kaggle/us-counties.csv"
df = pd.read_csv(covid_file, dtype=dict(fips=str))
df.head()
# Out:
#          date     county       state   fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061      1     0.0
# 2  2020-01-23  Snohomish  Washington  53061      1     0.0
# 3  2020-01-24       Cook    Illinois  17031      1     0.0
# 4  2020-01-24  Snohomish  Washington  53061      1     0.0

# %%
df.date[0]
# Out:
# '2020-01-21'
